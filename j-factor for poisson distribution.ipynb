# %% [markdown]
# # Poisson Point Process

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");

# %%
numbPoints
# Out:
# 4811

# %%
points = np.hstack((xx,yy,zz))

# %%
points.shape
# Out:
# (4811, 3)

# %%
#plotting 3d distribution of galaxies in space
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (10,10))

X_label = 'X_position'
Y_label = 'Y_position'
z_label = 'Z_position'
plt_title = 'early type galaxies'
ax = fig.add_subplot(111, projection = '3d',title = 'Poisson Point Process',xlabel=X_label,ylabel=Y_label,zlabel=z_label)

ax.scatter(xx , yy ,zz , s =1,  c = 'black'  )



#plt.savefig('3D-distribution-poisson.jpg')
plt.show()

# %%
def distance(x1,y1,z1,x2,y2,z2):
    return (((x2 - x1)**2 + (y2 - y1)**2 + (z2 - z1)**2)**0.5)

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G8 = []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G8.append(min(dist))
    
print(len(G8))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F1 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F1.append(min(dist))
    
print(len(F))

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G8 = []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G8.append(min(dist))
    
print(len(G8))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F8 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F8.append(min(dist))
    
print(len(F8))
# Out:
# 4947
# 4947

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G7 = []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G7.append(min(dist))
    
print(len(G7))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F7 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F7.append(min(dist))
    
print(len(F7))
# Out:
# 4952
# 4952

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G6= []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G6.append(min(dist))
    
print(len(G6))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F6 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F6.append(min(dist))
    
print(len(F6))
# Out:
# 4996
# 4996

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G5 = []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G5.append(min(dist))
    
print(len(G5))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F5 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F5.append(min(dist))
    
print(len(F5))
# Out:
# 4997
# 4997

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G4 = []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G4.append(min(dist))
    
print(len(G4))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F4 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F4.append(min(dist))
    
print(len(F4))
# Out:
# 4967
# 4967

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G3 = []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G3.append(min(dist))
print(len(G3))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F3 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F3.append(min(dist))
    
print(len(F3))
# Out:
# 5022
# 5022

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G2 = []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G2.append(min(dist))
    
print(len(G2))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F2 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F2.append(min(dist))
    
print(len(F2))
# Out:
# 4850
# 4850

# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
 
#Simulation window parameters
xMin=0;xMax=200;
yMin=0;yMax=200;
zMin=0;zMax=200;
xDelta=xMax-xMin;yDelta=yMax-yMin;zDelta=zMax-zMin #rectangle dimensions
vTotal=xDelta*yDelta*zDelta;
 
#Point process parameters
lambda0=5/8000; #intensity (ie mean density) of the Poisson process
 
#Simulate Poisson point process
numbPoints = scipy.stats.poisson( lambda0*vTotal ).rvs()#Poisson number of points
xx = xDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+xMin#x coordinates of Poisson points
yy = yDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+yMin#y coordinates of Poisson points
zz = zDelta*scipy.stats.uniform.rvs(0,1,((numbPoints,1)))+zMin
#plt.scatter(xx,yy, edgecolor='b', facecolor='none', alpha=0.5 )
#plt.xlabel("x"); plt.ylabel("y");
G1 = []
for i in range(len(xx)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xx[i],yy[i],zz[i],xx[j],yy[j],zz[j]))
    G1.append(min(dist))
    
print(len(G1))

xxr =np.random.uniform(0,200,len(xx))
yyr = np.random.uniform(0,200,len(xx))
zzr = np.random.uniform(0,200,len(xx))

F1 = []
for i in range(len(xxr)):
    dist = []
        
    for j in range(len(xx)):
        if (j != i ):
            dist.append(distance(xxr[i],yyr[i],zzr[i],xx[j],yy[j],zz[j]))
    F1.append(min(dist))
    
print(len(F1))
# Out:
# 5001
# 5001

# %%
g1 = np.array(G1)
g2 = np.array(G2)
g3 = np.array(G3)
g4 = np.array(G4)
g5 = np.array(G5)
g6 = np.array(G6)
g7 = np.array(G7)
g8 = np.array(G8)

# %%
f1 = np.array(F1)
f2 = np.array(F2)
f3 = np.array(F3)
f4 = np.array(F4)
f5 = np.array(F5)
f6 = np.array(F6)
f7 = np.array(F7)
f8 = np.array(F8)

# %%
bins = np.linspace(0,18,30)

# %%
counts_g1,bins,_ = plt.hist(g1,30,density=True,cumulative = True,range=(0,15))
counts_g2,bins,_  = plt.hist(g2,30,density=True,cumulative = True,range=(0,15))
counts_g3,bins,_  = plt.hist(g3,30,density=True,cumulative = True,range=(0,15))
counts_g4,bins,_  = plt.hist(g4,30,density=True,cumulative = True,range=(0,15))
counts_g5,bins,_  = plt.hist(g5,30,density=True,cumulative = True,range=(0,15))
counts_g6,bins,_  = plt.hist(g6,30,density=True,cumulative = True,range=(0,15))
counts_g7,bins,_  = plt.hist(g7,30,density=True,cumulative = True,range=(0,15))
counts_g8,bins,_  = plt.hist(g8,30,density=True,cumulative = True,range=(0,15))

# %%
counts_f1,bins,_  = plt.hist(f1,30,density=True,cumulative = True,range=(0,15))
counts_f2,bins,_  = plt.hist(f2,30,density=True,cumulative = True,range=(0,15))
counts_f3,bins,_  = plt.hist(f3,30,density=True,cumulative = True,range=(0,15))
counts_f4,bins,_  = plt.hist(f4,30,density=True,cumulative = True,range=(0,15))
counts_f5,bins,_  = plt.hist(f5,30,density=True,cumulative = True,range=(0,15))
counts_f6,bins,_  = plt.hist(f6,30,density=True,cumulative = True,range=(0,15))
counts_f7,bins,_  = plt.hist(f7,30,density=True,cumulative = True,range=(0,15))
counts_f8,bins,_  = plt.hist(f8,30,density=True,cumulative = True,range=(0,15))

# %%
j1 = (np.ones(30)-counts_g1)/(np.ones(30)-counts_f1)
j2 = (np.ones(30)-counts_g2)/(np.ones(30)-counts_f2)
j3 = (np.ones(30)-counts_g3)/(np.ones(30)-counts_f3)
j4 = (np.ones(30)-counts_g4)/(np.ones(30)-counts_f4)
j5 = (np.ones(30)-counts_g5)/(np.ones(30)-counts_f5)
j6 = (np.ones(30)-counts_g6)/(np.ones(30)-counts_f6)
j7 = (np.ones(30)-counts_g7)/(np.ones(30)-counts_f7)
j8 = (np.ones(30)-counts_g8)/(np.ones(30)-counts_f8)
# Out:
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
#
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   import sys

# %%
j1
# Out:
# array([0.99919904, 0.99879535, 0.99898389, 1.00059642, 1.00309542,
#        1.00209287, 0.99856203, 1.01126064, 1.00383216, 1.00966741,
#        1.01899734, 1.02294724, 1.0036122 , 1.01460183, 0.98426351,
#        0.97216674, 1.00625492, 0.97119147, 0.96279586, 0.93163113,
#        0.86873045, 0.92144229, 0.95790949, 0.99003966, 1.03719372,
#        1.10088106, 1.53969379, 1.50120144, 3.00240288,        nan])

# %%
j_mean = np.mean((j1[:-1],j2[:-1],j3[:-1],j4[:-1],j5[:-1],j6[:-1],j7[:-1],j8[:-1]),axis = 0)
j_std = np.std((j1[:-1],j2[:-1],j3[:-1],j4[:-1],j5[:-1],j6[:-1],j7[:-1],j8[:-1]),axis = 0)
# Out:
# C:\Users\zahra\Anaconda3\lib\site-packages\numpy\core\_methods.py:117: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
plt.plot(bins[:-2], j_mean)
plt.fill_between(bins[:-2], j_mean-j_std, j_mean+j_std,color = 'lightblue',lw=2)
plt.xlim(0,12)
plt.xlabel('r(Mpc/h)');
plt.ylabel('J - Factor');
plt.title('Poisson Point Process');
plt.grid('on')
plt.savefig('poisson.jpg')

# %% [markdown]
# # ################################

# %% [markdown]
# # Comparison with Simulation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py

# %%
data = pd.read_csv('z0.1m13.csv')

# %%
len(data)
# Out:
# 28485

# %%
data1 = data[(data['x']<200)&(data['y']<200)&(data['z']<200)]
data2 = data[(data['x']<200)&(data['y']<200)&(data['z']>200)]
data3 = data[(data['x']<200)&(data['y']>200)&(data['z']<200)]
data4 = data[(data['x']>200)&(data['y']<200)&(data['z']<200)]
data5 = data[(data['x']>200)&(data['y']>200)&(data['z']<200)]
data6 = data[(data['x']>200)&(data['y']<200)&(data['z']>200)]
data7 = data[(data['x']<200)&(data['y']>200)&(data['z']>200)]
data8 = data[(data['x']>200)&(data['y']>200)&(data['z']>200)]

# %%
x1 = data1['x'].values
y1 = data1['y'].values
z1 = data1['z'].values

x2 = data2['x'].values
y2 = data2['y'].values
z2 = data2['z'].values

x3 = data3['x'].values
y3 = data3['y'].values
z3 = data3['z'].values

x4 = data4['x'].values
y4 = data4['y'].values
z4 = data4['z'].values

x5 = data5['x'].values
y5 = data5['y'].values
z5 = data5['z'].values

x6 = data6['x'].values
y6 = data6['y'].values
z6 = data6['z'].values

x7 = data7['x'].values
y7 = data7['y'].values
z7 = data7['z'].values

x8 = data8['x'].values
y8 = data8['y'].values
z8 = data8['z'].values

# %%
minimum1 = []
for i in range(len(x1)):
    dist = []
        
    for j in range(len(x1)):
        if (j != i ):
            dist.append(distance(x1[i],y1[i],z1[i],x1[j],y1[j],z1[j]))
    minimum1.append(min(dist))
    
print(len(minimum1))

xr = np.random.uniform(np.amin(x1),np.amax(x1),len(x1))
yr = np.random.uniform(np.amin(y1),np.amax(y1),len(x1))
zr = np.random.uniform(np.amin(z1),np.amax(z1),len(x1))

minimum_r1 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x1)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x1[j],y1[j],z1[j]))
    minimum_r1.append(min(dist))
    
print(len(minimum_r1))
# Out:
# 3420
# 3420

# %%
minimum2 = []
for i in range(len(x2)):
    dist = []
        
    for j in range(len(x2)):
        if (j != i ):
            dist.append(distance(x2[i],y2[i],z2[i],x2[j],y2[j],z2[j]))
    minimum2.append(min(dist))
    
print(len(minimum2))

xr = np.random.uniform(np.amin(x2),np.amax(x2),len(x2))
yr = np.random.uniform(np.amin(y2),np.amax(y2),len(x2))
zr = np.random.uniform(np.amin(z2),np.amax(z2),len(x2))

minimum_r2 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x2)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x2[j],y2[j],z2[j]))
    minimum_r2.append(min(dist))
    
print(len(minimum_r2))
# Out:
# 3498
# 3498

# %%
minimum3 = []
for i in range(len(x3)):
    dist = []
        
    for j in range(len(x3)):
        if (j != i ):
            dist.append(distance(x3[i],y3[i],z3[i],x3[j],y3[j],z3[j]))
    minimum3.append(min(dist))
    
print(len(minimum3))

xr = np.random.uniform(np.amin(x3),np.amax(x3),len(x3))
yr = np.random.uniform(np.amin(y3),np.amax(y3),len(x3))
zr = np.random.uniform(np.amin(z3),np.amax(z3),len(x3))

minimum_r3 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x3)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x3[j],y3[j],z3[j]))
    minimum_r3.append(min(dist))
    
print(len(minimum_r3))
# Out:
# 3351
# 3351

# %%
minimum4 = []
for i in range(len(x4)):
    dist = []
        
    for j in range(len(x4)):
        if (j != i ):
            dist.append(distance(x4[i],y4[i],z4[i],x4[j],y4[j],z4[j]))
    minimum4.append(min(dist))
    
print(len(minimum4))

xr = np.random.uniform(np.amin(x4),np.amax(x4),len(x4))
yr = np.random.uniform(np.amin(y4),np.amax(y4),len(x4))
zr = np.random.uniform(np.amin(z4),np.amax(z4),len(x4))

minimum_r4 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x4)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x4[j],y4[j],z4[j]))
    minimum_r4.append(min(dist))
    
print(len(minimum_r4))
# Out:
# 3417
# 3417

# %%
minimum5 = []
for i in range(len(x5)):
    dist = []
        
    for j in range(len(x5)):
        if (j != i ):
            dist.append(distance(x5[i],y5[i],z5[i],x5[j],y5[j],z5[j]))
    minimum5.append(min(dist))
    
print(len(minimum5))

xr = np.random.uniform(np.amin(x5),np.amax(x5),len(x5))
yr = np.random.uniform(np.amin(y5),np.amax(y5),len(x5))
zr = np.random.uniform(np.amin(z5),np.amax(z5),len(x5))

minimum_r5 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x5)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x5[j],y5[j],z5[j]))
    minimum_r5.append(min(dist))
    
print(len(minimum_r5))
# Out:
# 3561
# 3561

# %%
minimum6 = []
for i in range(len(x6)):
    dist = []
        
    for j in range(len(x6)):
        if (j != i ):
            dist.append(distance(x6[i],y6[i],z6[i],x6[j],y6[j],z6[j]))
    minimum6.append(min(dist))
    
print(len(minimum6))

xr = np.random.uniform(np.amin(x6),np.amax(x6),len(x6))
yr = np.random.uniform(np.amin(y6),np.amax(y6),len(x6))
zr = np.random.uniform(np.amin(z6),np.amax(z6),len(x6))

minimum_r6 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x6)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x6[j],y6[j],z6[j]))
    minimum_r6.append(min(dist))
    
print(len(minimum_r6))
# Out:
# 3546
# 3546

# %%
minimum7 = []
for i in range(len(x7)):
    dist = []
        
    for j in range(len(x7)):
        if (j != i ):
            dist.append(distance(x7[i],y7[i],z7[i],x7[j],y7[j],z7[j]))
    minimum7.append(min(dist))
    
print(len(minimum7))

xr = np.random.uniform(np.amin(x7),np.amax(x7),len(x7))
yr = np.random.uniform(np.amin(y7),np.amax(y7),len(x7))
zr = np.random.uniform(np.amin(z7),np.amax(z7),len(x7))

minimum_r7 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x7)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x7[j],y7[j],z7[j]))
    minimum_r7.append(min(dist))
    
print(len(minimum_r7))
# Out:
# 3949
# 3949

# %%
minimum8 = []
for i in range(len(x8)):
    dist = []
        
    for j in range(len(x8)):
        if (j != i ):
            dist.append(distance(x8[i],y8[i],z8[i],x8[j],y8[j],z8[j]))
    minimum8.append(min(dist))
    
print(len(minimum8))

xr = np.random.uniform(np.amin(x8),np.amax(x8),len(x8))
yr = np.random.uniform(np.amin(y8),np.amax(y8),len(x8))
zr = np.random.uniform(np.amin(z8),np.amax(z8),len(x8))

minimum_r8 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x8)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x8[j],y8[j],z8[j]))
    minimum_r8.append(min(dist))
    
print(len(minimum_r8))
# Out:
# 3743
# 3743

# %%
minimum1 = np.array(minimum1)
minimum2 = np.array(minimum2)
minimum3 = np.array(minimum3)
minimum4 = np.array(minimum4)
minimum5 = np.array(minimum5)
minimum6 = np.array(minimum6)
minimum7 = np.array(minimum7)
minimum8 = np.array(minimum8)

minimum_r1 = np.array(minimum_r1)
minimum_r2 = np.array(minimum_r2)
minimum_r3 = np.array(minimum_r3)
minimum_r4 = np.array(minimum_r4)
minimum_r5 = np.array(minimum_r5)
minimum_r6 = np.array(minimum_r6)
minimum_r7 = np.array(minimum_r7)
minimum_r8 = np.array(minimum_r8)

# %%
#bins = np.linspace(0,18,30)

# %%
d_counts_g1,bins,_ = plt.hist(minimum1,30,density=True,cumulative = True,range=(0,15))
d_counts_g2,bins,_  = plt.hist(minimum2,30,density=True,cumulative = True,range=(0,15))
d_counts_g3,bins,_  = plt.hist(minimum3,30,density=True,cumulative = True,range=(0,15))
d_counts_g4,bins,_  = plt.hist(minimum4,30,density=True,cumulative = True,range=(0,15))
d_counts_g5,bins,_  = plt.hist(minimum5,30,density=True,cumulative = True,range=(0,15))
d_counts_g6,bins,_  = plt.hist(minimum6,30,density=True,cumulative = True,range=(0,15))
d_counts_g7,bins,_  = plt.hist(minimum7,30,density=True,cumulative = True,range=(0,15))
d_counts_g8,bins,_  = plt.hist(minimum8,30,density=True,cumulative = True,range=(0,15))

# %%
d_counts_f1,bins,_  = plt.hist(minimum_r1,30,density=True,cumulative = True,range=(0,15))
d_counts_f2,bins,_  = plt.hist(minimum_r2,30,density=True,cumulative = True,range=(0,15))
d_counts_f3,bins,_  = plt.hist(minimum_r3,30,density=True,cumulative = True,range=(0,15))
d_counts_f4,bins,_  = plt.hist(minimum_r4,30,density=True,cumulative = True,range=(0,15))
d_counts_f5,bins,_  = plt.hist(minimum_r5,30,density=True,cumulative = True,range=(0,15))
d_counts_f6,bins,_  = plt.hist(minimum_r6,30,density=True,cumulative = True,range=(0,15))
d_counts_f7,bins,_  = plt.hist(minimum_r7,30,density=True,cumulative = True,range=(0,15))
d_counts_f8,bins,_  = plt.hist(minimum_r8,30,density=True,cumulative = True,range=(0,15))

# %%
d_j1 = (np.ones(30)-d_counts_g1)/(np.ones(30)-d_counts_f1)
d_j2 = (np.ones(30)-d_counts_g2)/(np.ones(30)-d_counts_f2)
d_j3 = (np.ones(30)-d_counts_g3)/(np.ones(30)-d_counts_f3)
d_j4 = (np.ones(30)-d_counts_g4)/(np.ones(30)-d_counts_f4)
d_j5 = (np.ones(30)-d_counts_g5)/(np.ones(30)-d_counts_f5)
d_j6 = (np.ones(30)-d_counts_g6)/(np.ones(30)-d_counts_f6)
d_j7 = (np.ones(30)-d_counts_g7)/(np.ones(30)-d_counts_f7)
d_j8 = (np.ones(30)-d_counts_g8)/(np.ones(30)-d_counts_f8)
# Out:
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   """
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide

# %%
d_j_mean = np.mean((d_j1[:-1],d_j2[:-1],d_j3[:-1],d_j4[:-1],d_j5[:-1],d_j6[:-1],d_j7[:-1],d_j8[:-1]),axis = 0)
d_j_std = np.std((d_j1[:-1],d_j2[:-1],d_j3[:-1],d_j4[:-1],d_j5[:-1],d_j6[:-1],d_j7[:-1],d_j8[:-1]),axis = 0)

# %%
plt.plot(bins[:-2], j_mean,label='poisson point process')
plt.fill_between(bins[:-2], j_mean-j_std, j_mean+j_std,color = 'lightblue',lw=2)

plt.plot(bins[:-2], d_j_mean,color = 'lightgreen',label = 'Halos with $M_{halo}>10^{13}M_0$')
plt.fill_between(bins[:-2], d_j_mean-d_j_std, d_j_mean+d_j_std,color = 'darkgreen',lw=2)
plt.xlim(0,12)


plt.xlabel('r(Mpc/h)');
plt.ylabel('J - Factor')
#plt.title('Poisson Point Process');
plt.grid('on')
plt.legend(loc=0)
plt.savefig('piosson-smdpl.jpg')

# %% [markdown]
# # comparison with other mass

# %%
data = pd.read_csv('z0.14e12m8e12.csv')

# %%
data1 = data[(data['x']<200)&(data['y']<200)&(data['z']<200)]
data2 = data[(data['x']<200)&(data['y']<200)&(data['z']>200)]
data3 = data[(data['x']<200)&(data['y']>200)&(data['z']<200)]
data4 = data[(data['x']>200)&(data['y']<200)&(data['z']<200)]
data5 = data[(data['x']>200)&(data['y']>200)&(data['z']<200)]
data6 = data[(data['x']>200)&(data['y']<200)&(data['z']>200)]
data7 = data[(data['x']<200)&(data['y']>200)&(data['z']>200)]
data8 = data[(data['x']>200)&(data['y']>200)&(data['z']>200)]

# %%
x1 = data1['x'].values
y1 = data1['y'].values
z1 = data1['z'].values

x2 = data2['x'].values
y2 = data2['y'].values
z2 = data2['z'].values

x3 = data3['x'].values
y3 = data3['y'].values
z3 = data3['z'].values

x4 = data4['x'].values
y4 = data4['y'].values
z4 = data4['z'].values

x5 = data5['x'].values
y5 = data5['y'].values
z5 = data5['z'].values

x6 = data6['x'].values
y6 = data6['y'].values
z6 = data6['z'].values

x7 = data7['x'].values
y7 = data7['y'].values
z7 = data7['z'].values

x8 = data8['x'].values
y8 = data8['y'].values
z8 = data8['z'].values

# %%
minimum1 = []
for i in range(len(x1)):
    dist = []
        
    for j in range(len(x1)):
        if (j != i ):
            dist.append(distance(x1[i],y1[i],z1[i],x1[j],y1[j],z1[j]))
    minimum1.append(min(dist))
    
print(len(minimum1))

xr = np.random.uniform(np.amin(x1),np.amax(x1),len(x1))
yr = np.random.uniform(np.amin(y1),np.amax(y1),len(x1))
zr = np.random.uniform(np.amin(z1),np.amax(z1),len(x1))

minimum_r1 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x1)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x1[j],y1[j],z1[j]))
    minimum_r1.append(min(dist))
    
print(len(minimum_r1))
# Out:
# 4343
# 4343

# %%
minimum2 = []
for i in range(len(x2)):
    dist = []
        
    for j in range(len(x2)):
        if (j != i ):
            dist.append(distance(x2[i],y2[i],z2[i],x2[j],y2[j],z2[j]))
    minimum2.append(min(dist))
    
print(len(minimum2))

xr = np.random.uniform(np.amin(x2),np.amax(x2),len(x2))
yr = np.random.uniform(np.amin(y2),np.amax(y2),len(x2))
zr = np.random.uniform(np.amin(z2),np.amax(z2),len(x2))

minimum_r2 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x2)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x2[j],y2[j],z2[j]))
    minimum_r2.append(min(dist))
    
print(len(minimum_r2))
# Out:
# 4402
# 4402

# %%
minimum3 = []
for i in range(len(x3)):
    dist = []
        
    for j in range(len(x3)):
        if (j != i ):
            dist.append(distance(x3[i],y3[i],z3[i],x3[j],y3[j],z3[j]))
    minimum3.append(min(dist))
    
print(len(minimum3))

xr = np.random.uniform(np.amin(x3),np.amax(x3),len(x3))
yr = np.random.uniform(np.amin(y3),np.amax(y3),len(x3))
zr = np.random.uniform(np.amin(z3),np.amax(z3),len(x3))

minimum_r3 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x3)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x3[j],y3[j],z3[j]))
    minimum_r3.append(min(dist))
    
print(len(minimum_r3))
# Out:
# 4221
# 4221

# %%
minimum4 = []
for i in range(len(x4)):
    dist = []
        
    for j in range(len(x4)):
        if (j != i ):
            dist.append(distance(x4[i],y4[i],z4[i],x4[j],y4[j],z4[j]))
    minimum4.append(min(dist))
    
print(len(minimum4))

xr = np.random.uniform(np.amin(x4),np.amax(x4),len(x4))
yr = np.random.uniform(np.amin(y4),np.amax(y4),len(x4))
zr = np.random.uniform(np.amin(z4),np.amax(z4),len(x4))

minimum_r4 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x4)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x4[j],y4[j],z4[j]))
    minimum_r4.append(min(dist))
    
print(len(minimum_r4))
# Out:
# 4124
# 4124

# %%
minimum5 = []
for i in range(len(x5)):
    dist = []
        
    for j in range(len(x5)):
        if (j != i ):
            dist.append(distance(x5[i],y5[i],z5[i],x5[j],y5[j],z5[j]))
    minimum5.append(min(dist))
    
print(len(minimum5))

xr = np.random.uniform(np.amin(x5),np.amax(x5),len(x5))
yr = np.random.uniform(np.amin(y5),np.amax(y5),len(x5))
zr = np.random.uniform(np.amin(z5),np.amax(z5),len(x5))

minimum_r5 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x5)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x5[j],y5[j],z5[j]))
    minimum_r5.append(min(dist))
    
print(len(minimum_r5))
# Out:
# 4325
# 4325

# %%
minimum6 = []
for i in range(len(x6)):
    dist = []
        
    for j in range(len(x6)):
        if (j != i ):
            dist.append(distance(x6[i],y6[i],z6[i],x6[j],y6[j],z6[j]))
    minimum6.append(min(dist))
    
print(len(minimum6))

xr = np.random.uniform(np.amin(x6),np.amax(x6),len(x6))
yr = np.random.uniform(np.amin(y6),np.amax(y6),len(x6))
zr = np.random.uniform(np.amin(z6),np.amax(z6),len(x6))

minimum_r6 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x6)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x6[j],y6[j],z6[j]))
    minimum_r6.append(min(dist))
    
print(len(minimum_r6))
# Out:
# 4394
# 4394

# %%
minimum7 = []
for i in range(len(x7)):
    dist = []
        
    for j in range(len(x7)):
        if (j != i ):
            dist.append(distance(x7[i],y7[i],z7[i],x7[j],y7[j],z7[j]))
    minimum7.append(min(dist))
    
print(len(minimum7))

xr = np.random.uniform(np.amin(x7),np.amax(x7),len(x7))
yr = np.random.uniform(np.amin(y7),np.amax(y7),len(x7))
zr = np.random.uniform(np.amin(z7),np.amax(z7),len(x7))

minimum_r7 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x7)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x7[j],y7[j],z7[j]))
    minimum_r7.append(min(dist))
    
print(len(minimum_r7))
# Out:
# 4643
# 4643

# %%
minimum8 = []
for i in range(len(x8)):
    dist = []
        
    for j in range(len(x8)):
        if (j != i ):
            dist.append(distance(x8[i],y8[i],z8[i],x8[j],y8[j],z8[j]))
    minimum8.append(min(dist))
    
print(len(minimum8))

xr = np.random.uniform(np.amin(x8),np.amax(x8),len(x8))
yr = np.random.uniform(np.amin(y8),np.amax(y8),len(x8))
zr = np.random.uniform(np.amin(z8),np.amax(z8),len(x8))

minimum_r8 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x8)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x8[j],y8[j],z8[j]))
    minimum_r8.append(min(dist))
    
print(len(minimum_r8))
# Out:
# 4459
# 4459

# %%
minimum1 = np.array(minimum1)
minimum2 = np.array(minimum2)
minimum3 = np.array(minimum3)
minimum4 = np.array(minimum4)
minimum5 = np.array(minimum5)
minimum6 = np.array(minimum6)
minimum7 = np.array(minimum7)
minimum8 = np.array(minimum8)

minimum_r1 = np.array(minimum_r1)
minimum_r2 = np.array(minimum_r2)
minimum_r3 = np.array(minimum_r3)
minimum_r4 = np.array(minimum_r4)
minimum_r5 = np.array(minimum_r5)
minimum_r6 = np.array(minimum_r6)
minimum_r7 = np.array(minimum_r7)
minimum_r8 = np.array(minimum_r8)

# %%
d12_counts_g1,bins,_ = plt.hist(minimum1,30,density=True,cumulative = True,range=(0,15))
d12_counts_g2,bins,_  = plt.hist(minimum2,30,density=True,cumulative = True,range=(0,15))
d12_counts_g3,bins,_  = plt.hist(minimum3,30,density=True,cumulative = True,range=(0,15))
d12_counts_g4,bins,_  = plt.hist(minimum4,30,density=True,cumulative = True,range=(0,15))
d12_counts_g5,bins,_  = plt.hist(minimum5,30,density=True,cumulative = True,range=(0,15))
d12_counts_g6,bins,_  = plt.hist(minimum6,30,density=True,cumulative = True,range=(0,15))
d12_counts_g7,bins,_  = plt.hist(minimum7,30,density=True,cumulative = True,range=(0,15))
d12_counts_g8,bins,_  = plt.hist(minimum8,30,density=True,cumulative = True,range=(0,15))

# %%
d12_counts_f1,bins,_  = plt.hist(minimum_r1,30,density=True,cumulative = True,range=(0,15))
d12_counts_f2,bins,_  = plt.hist(minimum_r2,30,density=True,cumulative = True,range=(0,15))
d12_counts_f3,bins,_  = plt.hist(minimum_r3,30,density=True,cumulative = True,range=(0,15))
d12_counts_f4,bins,_  = plt.hist(minimum_r4,30,density=True,cumulative = True,range=(0,15))
d12_counts_f5,bins,_  = plt.hist(minimum_r5,30,density=True,cumulative = True,range=(0,15))
d12_counts_f6,bins,_  = plt.hist(minimum_r6,30,density=True,cumulative = True,range=(0,15))
d12_counts_f7,bins,_  = plt.hist(minimum_r7,30,density=True,cumulative = True,range=(0,15))
d12_counts_f8,bins,_  = plt.hist(minimum_r8,30,density=True,cumulative = True,range=(0,15))

# %%
d12_j1 = (np.ones(30)-d12_counts_g1)/(np.ones(30)-d12_counts_f1)
d12_j2 = (np.ones(30)-d12_counts_g2)/(np.ones(30)-d12_counts_f2)
d12_j3 = (np.ones(30)-d12_counts_g3)/(np.ones(30)-d12_counts_f3)
d12_j4 = (np.ones(30)-d12_counts_g4)/(np.ones(30)-d12_counts_f4)
d12_j5 = (np.ones(30)-d12_counts_g5)/(np.ones(30)-d12_counts_f5)
d12_j6 = (np.ones(30)-d12_counts_g6)/(np.ones(30)-d12_counts_f6)
d12_j7 = (np.ones(30)-d12_counts_g7)/(np.ones(30)-d12_counts_f7)
d12_j8 = (np.ones(30)-d12_counts_g8)/(np.ones(30)-d12_counts_f8)
# Out:
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
#
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %%
d12_j_mean = np.mean((d12_j1[:-1],d12_j2[:-1],d12_j3[:-1],d12_j4[:-1],d12_j5[:-1],d12_j6[:-1],d12_j7[:-1],d12_j8[:-1]),axis = 0)
d12_j_std = np.std((d12_j1[:-1],d12_j2[:-1],d12_j3[:-1],d12_j4[:-1],d12_j5[:-1],d12_j6[:-1],d12_j7[:-1],d12_j8[:-1]),axis = 0)

# %%
plt.plot(bins[:-2], j_mean,label='poisson point process')
plt.fill_between(bins[:-2], j_mean-j_std, j_mean+j_std,color = 'lightblue',lw=2)

plt.plot(bins[:-2], d_j_mean,color = 'lightgreen',label = 'Halos with $M_{halo}>10^{13}M_0$')
plt.fill_between(bins[:-2], d_j_mean-d_j_std, d_j_mean+d_j_std,color = 'darkgreen',lw=2)
plt.xlim(0,12)


plt.plot(bins[:-2], d12_j_mean,color = 'navy',label = 'Halos with $4x10^{12}M_0<M_{halo}<8x10^{12}M_0$')
plt.fill_between(bins[:-2], d12_j_mean-d12_j_std, d12_j_mean+d12_j_std,color = 'navy',lw=2)


plt.xlabel('r(Mpc/h)');
plt.ylabel('J - Factor')
#plt.title('Poisson Point Process');
plt.grid('on')
plt.legend(loc=0)
#plt.savefig('piosson-smdpl.jpg')

# %%
data = pd.read_csv('z0.11e12m3e12.csv')

# %%
data = data[(data['mass']>1.5e12)&(data['mass']<2e12)]

# %%
len(data)
# Out:
# 41818

# %%
data1 = data[(data['x']<200)&(data['y']<200)&(data['z']<200)]
data2 = data[(data['x']<200)&(data['y']<200)&(data['z']>200)]
data3 = data[(data['x']<200)&(data['y']>200)&(data['z']<200)]
data4 = data[(data['x']>200)&(data['y']<200)&(data['z']<200)]
data5 = data[(data['x']>200)&(data['y']>200)&(data['z']<200)]
data6 = data[(data['x']>200)&(data['y']<200)&(data['z']>200)]
data7 = data[(data['x']<200)&(data['y']>200)&(data['z']>200)]
data8 = data[(data['x']>200)&(data['y']>200)&(data['z']>200)]

# %%
x1 = data1['x'].values
y1 = data1['y'].values
z1 = data1['z'].values

x2 = data2['x'].values
y2 = data2['y'].values
z2 = data2['z'].values

x3 = data3['x'].values
y3 = data3['y'].values
z3 = data3['z'].values

x4 = data4['x'].values
y4 = data4['y'].values
z4 = data4['z'].values

x5 = data5['x'].values
y5 = data5['y'].values
z5 = data5['z'].values

x6 = data6['x'].values
y6 = data6['y'].values
z6 = data6['z'].values

x7 = data7['x'].values
y7 = data7['y'].values
z7 = data7['z'].values

x8 = data8['x'].values
y8 = data8['y'].values
z8 = data8['z'].values

# %%
x1.shape
# Out:
# (5172,)

# %%
minimum1 = []
for i in range(len(x1)):
    dist = []
        
    for j in range(len(x1)):
        if (j != i ):
            dist.append(distance(x1[i],y1[i],z1[i],x1[j],y1[j],z1[j]))
    minimum1.append(min(dist))
    
print(len(minimum1))

xr = np.random.uniform(np.amin(x1),np.amax(x1),len(x1))
yr = np.random.uniform(np.amin(y1),np.amax(y1),len(x1))
zr = np.random.uniform(np.amin(z1),np.amax(z1),len(x1))

minimum_r1 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x1)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x1[j],y1[j],z1[j]))
    minimum_r1.append(min(dist))
    
print(len(minimum_r1))
# Out:
# 5172
# 5172

# %%
minimum2 = []
for i in range(len(x2)):
    dist = []
        
    for j in range(len(x2)):
        if (j != i ):
            dist.append(distance(x2[i],y2[i],z2[i],x2[j],y2[j],z2[j]))
    minimum2.append(min(dist))
    
print(len(minimum2))

xr = np.random.uniform(np.amin(x2),np.amax(x2),len(x2))
yr = np.random.uniform(np.amin(y2),np.amax(y2),len(x2))
zr = np.random.uniform(np.amin(z2),np.amax(z2),len(x2))

minimum_r2 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x2)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x2[j],y2[j],z2[j]))
    minimum_r2.append(min(dist))
    
print(len(minimum_r2))
# Out:
# 5279
# 5279

# %%
minimum3 = []
for i in range(len(x3)):
    dist = []
        
    for j in range(len(x3)):
        if (j != i ):
            dist.append(distance(x3[i],y3[i],z3[i],x3[j],y3[j],z3[j]))
    minimum3.append(min(dist))
    
print(len(minimum3))

xr = np.random.uniform(np.amin(x3),np.amax(x3),len(x3))
yr = np.random.uniform(np.amin(y3),np.amax(y3),len(x3))
zr = np.random.uniform(np.amin(z3),np.amax(z3),len(x3))

minimum_r3 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x3)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x3[j],y3[j],z3[j]))
    minimum_r3.append(min(dist))
    
print(len(minimum_r3))
# Out:
# 5083
# 5083

# %%
minimum4 = []
for i in range(len(x4)):
    dist = []
        
    for j in range(len(x4)):
        if (j != i ):
            dist.append(distance(x4[i],y4[i],z4[i],x4[j],y4[j],z4[j]))
    minimum4.append(min(dist))
    
print(len(minimum4))

xr = np.random.uniform(np.amin(x4),np.amax(x4),len(x4))
yr = np.random.uniform(np.amin(y4),np.amax(y4),len(x4))
zr = np.random.uniform(np.amin(z4),np.amax(z4),len(x4))

minimum_r4 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x4)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x4[j],y4[j],z4[j]))
    minimum_r4.append(min(dist))
    
print(len(minimum_r4))
# Out:
# 4938
# 4938

# %%
minimum5 = []
for i in range(len(x5)):
    dist = []
        
    for j in range(len(x5)):
        if (j != i ):
            dist.append(distance(x5[i],y5[i],z5[i],x5[j],y5[j],z5[j]))
    minimum5.append(min(dist))
    
print(len(minimum5))

xr = np.random.uniform(np.amin(x5),np.amax(x5),len(x5))
yr = np.random.uniform(np.amin(y5),np.amax(y5),len(x5))
zr = np.random.uniform(np.amin(z5),np.amax(z5),len(x5))

minimum_r5 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x5)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x5[j],y5[j],z5[j]))
    minimum_r5.append(min(dist))
    
print(len(minimum_r5))
# Out:
# 5344
# 5344

# %%
minimum6 = []
for i in range(len(x6)):
    dist = []
        
    for j in range(len(x6)):
        if (j != i ):
            dist.append(distance(x6[i],y6[i],z6[i],x6[j],y6[j],z6[j]))
    minimum6.append(min(dist))
    
print(len(minimum6))

xr = np.random.uniform(np.amin(x6),np.amax(x6),len(x6))
yr = np.random.uniform(np.amin(y6),np.amax(y6),len(x6))
zr = np.random.uniform(np.amin(z6),np.amax(z6),len(x6))

minimum_r6 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x6)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x6[j],y6[j],z6[j]))
    minimum_r6.append(min(dist))
    
print(len(minimum_r6))
# Out:
# 5098
# 5098

# %%
minimum7 = []
for i in range(len(x7)):
    dist = []
        
    for j in range(len(x7)):
        if (j != i ):
            dist.append(distance(x7[i],y7[i],z7[i],x7[j],y7[j],z7[j]))
    minimum7.append(min(dist))
    
print(len(minimum7))

xr = np.random.uniform(np.amin(x7),np.amax(x7),len(x7))
yr = np.random.uniform(np.amin(y7),np.amax(y7),len(x7))
zr = np.random.uniform(np.amin(z7),np.amax(z7),len(x7))

minimum_r7 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x7)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x7[j],y7[j],z7[j]))
    minimum_r7.append(min(dist))
    
print(len(minimum_r7))
# Out:
# 5566
# 5566

# %%
minimum8 = []
for i in range(len(x8)):
    dist = []
        
    for j in range(len(x8)):
        if (j != i ):
            dist.append(distance(x8[i],y8[i],z8[i],x8[j],y8[j],z8[j]))
    minimum8.append(min(dist))
    
print(len(minimum8))

xr = np.random.uniform(np.amin(x8),np.amax(x8),len(x8))
yr = np.random.uniform(np.amin(y8),np.amax(y8),len(x8))
zr = np.random.uniform(np.amin(z8),np.amax(z8),len(x8))

minimum_r8 = []
for i in range(len(xr)):
    dist = []
        
    for j in range(len(x8)):
        if (j != i ):
            dist.append(distance(xr[i],yr[i],zr[i],x8[j],y8[j],z8[j]))
    minimum_r8.append(min(dist))
    
print(len(minimum_r8))
# Out:
# 5337
# 5337

# %%
minimum1 = np.array(minimum1)
minimum2 = np.array(minimum2)
minimum3 = np.array(minimum3)
minimum4 = np.array(minimum4)
minimum5 = np.array(minimum5)
minimum6 = np.array(minimum6)
minimum7 = np.array(minimum7)
minimum8 = np.array(minimum8)

minimum_r1 = np.array(minimum_r1)
minimum_r2 = np.array(minimum_r2)
minimum_r3 = np.array(minimum_r3)
minimum_r4 = np.array(minimum_r4)
minimum_r5 = np.array(minimum_r5)
minimum_r6 = np.array(minimum_r6)
minimum_r7 = np.array(minimum_r7)
minimum_r8 = np.array(minimum_r8)

# %%
dd12_counts_g1,bins,_ = plt.hist(minimum1,30,density=True,cumulative = True,range=(0,15))
dd12_counts_g2,bins,_  = plt.hist(minimum2,30,density=True,cumulative = True,range=(0,15))
dd12_counts_g3,bins,_  = plt.hist(minimum3,30,density=True,cumulative = True,range=(0,15))
dd12_counts_g4,bins,_  = plt.hist(minimum4,30,density=True,cumulative = True,range=(0,15))
dd12_counts_g5,bins,_  = plt.hist(minimum5,30,density=True,cumulative = True,range=(0,15))
dd12_counts_g6,bins,_  = plt.hist(minimum6,30,density=True,cumulative = True,range=(0,15))
dd12_counts_g7,bins,_  = plt.hist(minimum7,30,density=True,cumulative = True,range=(0,15))
dd12_counts_g8,bins,_  = plt.hist(minimum8,30,density=True,cumulative = True,range=(0,15))

# %%
dd12_counts_f1,bins,_  = plt.hist(minimum_r1,30,density=True,cumulative = True,range=(0,15))
dd12_counts_f2,bins,_  = plt.hist(minimum_r2,30,density=True,cumulative = True,range=(0,15))
dd12_counts_f3,bins,_  = plt.hist(minimum_r3,30,density=True,cumulative = True,range=(0,15))
dd12_counts_f4,bins,_  = plt.hist(minimum_r4,30,density=True,cumulative = True,range=(0,15))
dd12_counts_f5,bins,_  = plt.hist(minimum_r5,30,density=True,cumulative = True,range=(0,15))
dd12_counts_f6,bins,_  = plt.hist(minimum_r6,30,density=True,cumulative = True,range=(0,15))
dd12_counts_f7,bins,_  = plt.hist(minimum_r7,30,density=True,cumulative = True,range=(0,15))
dd12_counts_f8,bins,_  = plt.hist(minimum_r8,30,density=True,cumulative = True,range=(0,15))

# %%
dd12_j1 = (np.ones(30)-dd12_counts_g1)/(np.ones(30)-dd12_counts_f1)
dd12_j2 = (np.ones(30)-dd12_counts_g2)/(np.ones(30)-dd12_counts_f2)
dd12_j3 = (np.ones(30)-dd12_counts_g3)/(np.ones(30)-dd12_counts_f3)
dd12_j4 = (np.ones(30)-dd12_counts_g4)/(np.ones(30)-dd12_counts_f4)
dd12_j5 = (np.ones(30)-dd12_counts_g5)/(np.ones(30)-dd12_counts_f5)
dd12_j6 = (np.ones(30)-dd12_counts_g6)/(np.ones(30)-dd12_counts_f6)
dd12_j7 = (np.ones(30)-dd12_counts_g7)/(np.ones(30)-dd12_counts_f7)
dd12_j8 = (np.ones(30)-dd12_counts_g8)/(np.ones(30)-dd12_counts_f8)
# Out:
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
#
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\zahra\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %%
dd12_j_mean = np.mean((dd12_j1[:-1],dd12_j2[:-1],dd12_j3[:-1],dd12_j4[:-1],dd12_j5[:-1],dd12_j6[:-1],dd12_j7[:-1],dd12_j8[:-1]),axis = 0)
dd12_j_std = np.std((dd12_j1[:-1],dd12_j2[:-1],dd12_j3[:-1],dd12_j4[:-1],dd12_j5[:-1],dd12_j6[:-1],dd12_j7[:-1],dd12_j8[:-1]),axis = 0)

# %%
fig = plt.figure(figsize = (13,8))
ax = fig.add_subplot(111,title='Simulation:SMDPL',xlabel = 'r(Mpc/h)',ylabel='J - Factor')
ax.plot(bins[:-2], j_mean,label='poisson point process')
ax.fill_between(bins[:-2], j_mean-j_std, j_mean+j_std,color = 'lightblue',lw=2)

ax.plot(bins[:-2], dd12_j_mean,color = 'magenta',label = 'Halos with $1.5x10^{12}M_0<M_{halo}<2x10^{12}M_0$')
ax.fill_between(bins[:-2], dd12_j_mean-dd12_j_std, dd12_j_mean+dd12_j_std,color = 'pink',lw=2)


ax.plot(bins[:-2], d12_j_mean,color = 'green',label = 'Halos with $4x10^{12}M_0<M_{halo}<8x10^{12}M_0$')
ax.fill_between(bins[:-2], d12_j_mean-d12_j_std, d12_j_mean+d12_j_std,color = 'lightgreen',lw=2)


ax.plot(bins[:-2], d_j_mean,color = 'tomato',label = 'Halos with $M_{halo}>10^{13}M_0$')
ax.fill_between(bins[:-2], d_j_mean-d_j_std, d_j_mean+d_j_std,color = 'darkred',lw=2)
plt.xlim(0,12)





#plt.xlabel('r(Mpc/h)');
#plt.ylabel('J - Factor')
#plt.title('Poisson Point Process');
plt.grid('on')
plt.legend(loc=0)
plt.savefig('comparison.jpg')
